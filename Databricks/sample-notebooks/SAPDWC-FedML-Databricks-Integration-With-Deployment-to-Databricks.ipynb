# %% [markdown]
# ## Sample notebook showing end-to-end Sales prediction use case using the FedML Databricks Library.
#
# ### The FedML Databricks Library reads the training data via SAP Data Warehouse Cloud, trains the model in Databricks, deploys the model in Databricks and the inference result is written back to SAP Data Warehouse Cloud.

# %% [markdown]
# ### Install fedml-databricks library

# %%
pip install fedml-databricks --no-cache-dir --upgrade --force-reinstall

# %%
import numpy as np
import pandas as pd
import json
from fedml_databricks import DbConnection,predict
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ### 1. Connect to SAP Data Warehouse Cloud , Explore & Acquire Data

# %% [markdown]
# #### 1.1 Create a Databricks Secret to store the SAP Data Warehouse Cloud connection credentials securely and connect to SAP Data Warehouse Cloud.
#
# Create a Databricks Secret Scope by referring the [(link)](https://docs.databricks.com/security/secrets/secret-scopes.html#create-a-databricks-backed-secret-scope). Then, create the Databricks Secret containing SAP DWC credentials in the form of json, using the [(link)](https://docs.databricks.com/security/secrets/secrets.html#create-a-secret-in-a-databricks-backed-scope). The  SAP DWC connection credentials can be obtained by completing the pre-requisite step using the [(link)](https://github.com/SAP-samples/data-warehouse-cloud-fedml/blob/main/Databricks/docs/dbconnection.md#pre-requisite)

# %%
config_str=dbutils.secrets.get('<databriks-secret-scope>','<databricks-secret-key>')
config=json.loads(config_str)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
dwc = DbConnection(dict_obj=config)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# #### 1.2 List all business models available to read from

# %%
data= dwc.get_schema_views()
data
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[4]: ([(&#39;Country_Location&#39;, &#39;ROW&#39;),
#   (&#39;PP_Gross_Sales_S4&#39;, &#39;ROW&#39;),
#   (&#39;ProjectedSalesVolume_View&#39;, &#39;ROW&#39;),
#   (&#39;SAP.TIME.VIEW_DIMENSION_DAY&#39;, &#39;ROW&#39;),
#   (&#39;SAP.TIME.VIEW_DIMENSION_MONTH&#39;, &#39;ROW&#39;),
#   (&#39;SAP.TIME.VIEW_DIMENSION_QUARTER&#39;, &#39;ROW&#39;),
#   (&#39;SAP.TIME.VIEW_DIMENSION_YEAR&#39;, &#39;ROW&#39;),
#   (&#39;Sales_vs_Outlook_Reporting&#39;, &#39;ROW&#39;),
#   (&#39;V_Economic_Outlook__OECD&#39;, &#39;ROW&#39;)],
#  [&#39;VIEW_NAME&#39;, &#39;VIEW_TYPE&#39;])</div>

# %% [markdown]
# #### 1.3 Query the SAP DWC data using SQL Queries. Get the data as a PySpark DataFrame

# %%
spark_df=dwc.execute_query_pyspark('SELECT * FROM \"DEMOSALESANALYSIS\".\"PP_Gross_Sales_S4\"')
spark_df.show(truncate=False)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------------+-------------+----------+----+--------------------------------------+----------------------+------------+-----+-------+--------------+-------------+
# Country_Label|Country      |YEAR_Label|YEAR|HarmonizedCountryDimension_COUNTRYCODE|Projected Sales Volume|Gross amount|Value|Value_1|Gross amount_1|GROSSAMOUNT_1|
# +-------------+-------------+----------+----+--------------------------------------+----------------------+------------+-----+-------+--------------+-------------+
# United States|United States|2020      |2020|US                                    |104797.12             |104797.12   |0E-10|0E-10  |0.00          |0.00         |
# United States|United States|2021      |2021|US                                    |104797.12             |104797.12   |0E-10|0E-10  |0.00          |0.00         |
# United States|United States|2022      |2022|US                                    |104797.12             |104797.12   |0E-10|0E-10  |0.00          |0.00         |
# United States|United States|2023      |2023|US                                    |104797.12             |104797.12   |0E-10|0E-10  |0.00          |0.00         |
# United States|United States|2020      |2020|US                                    |34197.75              |34197.75    |0E-10|0E-10  |0.00          |0.00         |
# United States|United States|2021      |2021|US                                    |34197.75              |34197.75    |0E-10|0E-10  |0.00          |0.00         |
# United States|United States|2022      |2022|US                                    |34197.75              |34197.75    |0E-10|0E-10  |0.00          |0.00         |
# United States|United States|2023      |2023|US                                    |34197.75              |34197.75    |0E-10|0E-10  |0.00          |0.00         |
# United States|United States|2020      |2020|US                                    |46940.60              |46940.60    |0E-10|0E-10  |0.00          |0.00         |
# United States|United States|2021      |2021|US                                    |46940.60              |46940.60    |0E-10|0E-10  |0.00          |0.00         |
# United States|United States|2022      |2022|US                                    |46940.60              |46940.60    |0E-10|0E-10  |0.00          |0.00         |
# United States|United States|2023      |2023|US                                    |46940.60              |46940.60    |0E-10|0E-10  |0.00          |0.00         |
# United States|United States|2020      |2020|US                                    |87263.99              |87263.99    |0E-10|0E-10  |0.00          |0.00         |
# United States|United States|2021      |2021|US                                    |87263.99              |87263.99    |0E-10|0E-10  |0.00          |0.00         |
# United States|United States|2022      |2022|US                                    |87263.99              |87263.99    |0E-10|0E-10  |0.00          |0.00         |
# United States|United States|2023      |2023|US                                    |87263.99              |87263.99    |0E-10|0E-10  |0.00          |0.00         |
# United States|United States|2020      |2020|US                                    |92230.86              |92230.86    |0E-10|0E-10  |0.00          |0.00         |
# United States|United States|2021      |2021|US                                    |92230.86              |92230.86    |0E-10|0E-10  |0.00          |0.00         |
# United States|United States|2022      |2022|US                                    |92230.86              |92230.86    |0E-10|0E-10  |0.00          |0.00         |
# United States|United States|2023      |2023|US                                    |92230.86              |92230.86    |0E-10|0E-10  |0.00          |0.00         |
# +-------------+-------------+----------+----+--------------------------------------+----------------------+------------+-----+-------+--------------+-------------+
# only showing top 20 rows
#
# </div>

# %% [markdown]
# ##### 1.3.1 Get Insights from the data. In the below cell, we get the average projected sales for the year '2021'

# %%
average_sales_for_2021_df=spark_df.filter(spark_df['YEAR_Label']=='2021').groupBy().avg('Projected Sales Volume')
average_sales_for_2021_df.show(truncate=False)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+---------------------------+
# avg(Projected Sales Volume)|
# +---------------------------+
# 72417.156321               |
# +---------------------------+
#
# </div>

# %% [markdown]
# ##### 1.3.2 Convert the PySpark DataFrame to Pandas DataFrame

# %%
dataframe=spark_df.toPandas()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">/databricks/spark/python/pyspark/sql/pandas/utils.py:79: UserWarning: The conversion of DecimalType columns is inefficient and may take a long time. Column names: [Projected Sales Volume, Gross amount, Value, Value_1, Gross amount_1, GROSSAMOUNT_1] If those columns are not necessary, you may consider dropping them or converting to primitive types before the conversion.
#   warnings.warn(
# </div>

# %% [markdown]
# #### 1.4 Preprocess the data

# %% [markdown]
# ##### 1.4.1 Replace the zero values with the mean values in few of the selected columns

# %%
dataframe=dataframe.replace({'GROSSAMOUNT_1': {0: dataframe['GROSSAMOUNT_1'].mean(skipna=True)}}) 
dataframe=dataframe.replace({'Gross amount': {0: dataframe['Gross amount'].mean(skipna=True)}}) 
dataframe=dataframe.replace({'Projected Sales Volume': {0: dataframe['Projected Sales Volume'].mean(skipna=True)}})
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ##### 1.4.2 Perform One Hot Encoding on the Categorical columns

# %%
from sklearn.preprocessing import OneHotEncoder
def one_hot_encode(df,column):
    encoder = OneHotEncoder(handle_unknown='ignore')
    encoder_df = pd.DataFrame(encoder.fit_transform(df[[column]]).toarray())
    encoded_columns = encoder.get_feature_names([column])
    encoder_df.columns = encoded_columns
    return encoder_df,encoded_columns
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
encoded_column_names=[]
for column in ['Country','YEAR']:
    encoded_df,encoded_columns=one_hot_encode(dataframe,column)
    dataframe = dataframe.join(encoded_df)
    encoded_column_names += encoded_columns.tolist()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
dataframe.head(10)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[11]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Country_Label</th>
#       <th>Country</th>
#       <th>YEAR_Label</th>
#       <th>YEAR</th>
#       <th>HarmonizedCountryDimension_COUNTRYCODE</th>
#       <th>Projected Sales Volume</th>
#       <th>Gross amount</th>
#       <th>Value</th>
#       <th>Value_1</th>
#       <th>Gross amount_1</th>
#       <th>GROSSAMOUNT_1</th>
#       <th>Country_Australia</th>
#       <th>Country_Canada</th>
#       <th>Country_France</th>
#       <th>Country_Germany</th>
#       <th>Country_India</th>
#       <th>Country_United Kingdom</th>
#       <th>Country_United States</th>
#       <th>YEAR_2020</th>
#       <th>YEAR_2021</th>
#       <th>YEAR_2022</th>
#       <th>YEAR_2023</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>United States</td>
#       <td>United States</td>
#       <td>2020</td>
#       <td>2020</td>
#       <td>US</td>
#       <td>104797.12</td>
#       <td>104797.12</td>
#       <td>0E-10</td>
#       <td>0E-10</td>
#       <td>0.00</td>
#       <td>14536.153063</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>1.0</td>
#       <td>1.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>United States</td>
#       <td>United States</td>
#       <td>2021</td>
#       <td>2021</td>
#       <td>US</td>
#       <td>104797.12</td>
#       <td>104797.12</td>
#       <td>0E-10</td>
#       <td>0E-10</td>
#       <td>0.00</td>
#       <td>14536.153063</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>1.0</td>
#       <td>0.0</td>
#       <td>1.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>United States</td>
#       <td>United States</td>
#       <td>2022</td>
#       <td>2022</td>
#       <td>US</td>
#       <td>104797.12</td>
#       <td>104797.12</td>
#       <td>0E-10</td>
#       <td>0E-10</td>
#       <td>0.00</td>
#       <td>14536.153063</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>1.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>1.0</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>United States</td>
#       <td>United States</td>
#       <td>2023</td>
#       <td>2023</td>
#       <td>US</td>
#       <td>104797.12</td>
#       <td>104797.12</td>
#       <td>0E-10</td>
#       <td>0E-10</td>
#       <td>0.00</td>
#       <td>14536.153063</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>1.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>United States</td>
#       <td>United States</td>
#       <td>2020</td>
#       <td>2020</td>
#       <td>US</td>
#       <td>34197.75</td>
#       <td>34197.75</td>
#       <td>0E-10</td>
#       <td>0E-10</td>
#       <td>0.00</td>
#       <td>14536.153063</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>1.0</td>
#       <td>1.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>United States</td>
#       <td>United States</td>
#       <td>2021</td>
#       <td>2021</td>
#       <td>US</td>
#       <td>34197.75</td>
#       <td>34197.75</td>
#       <td>0E-10</td>
#       <td>0E-10</td>
#       <td>0.00</td>
#       <td>14536.153063</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>1.0</td>
#       <td>0.0</td>
#       <td>1.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>United States</td>
#       <td>United States</td>
#       <td>2022</td>
#       <td>2022</td>
#       <td>US</td>
#       <td>34197.75</td>
#       <td>34197.75</td>
#       <td>0E-10</td>
#       <td>0E-10</td>
#       <td>0.00</td>
#       <td>14536.153063</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>1.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>1.0</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>United States</td>
#       <td>United States</td>
#       <td>2023</td>
#       <td>2023</td>
#       <td>US</td>
#       <td>34197.75</td>
#       <td>34197.75</td>
#       <td>0E-10</td>
#       <td>0E-10</td>
#       <td>0.00</td>
#       <td>14536.153063</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>1.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>United States</td>
#       <td>United States</td>
#       <td>2020</td>
#       <td>2020</td>
#       <td>US</td>
#       <td>46940.60</td>
#       <td>46940.60</td>
#       <td>0E-10</td>
#       <td>0E-10</td>
#       <td>0.00</td>
#       <td>14536.153063</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>1.0</td>
#       <td>1.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>United States</td>
#       <td>United States</td>
#       <td>2021</td>
#       <td>2021</td>
#       <td>US</td>
#       <td>46940.60</td>
#       <td>46940.60</td>
#       <td>0E-10</td>
#       <td>0E-10</td>
#       <td>0.00</td>
#       <td>14536.153063</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>1.0</td>
#       <td>0.0</td>
#       <td>1.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# ### 2. Now, using the data,  train the model

# %%
import os,json
import pandas as pd
import mlflow 
from sklearn.linear_model import LinearRegression
import numpy as np
from sklearn.model_selection import train_test_split

label_column = 'Projected Sales Volume'
y = dataframe[label_column]
dataframe.drop(label_column, axis=1, inplace=True)
X_train, X_test, y_train, y_test = train_test_split(dataframe , y, test_size=0.3)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# #### 2.1 Use the columns required for training the model

# %%
train_columns=['GROSSAMOUNT_1','Gross amount']+encoded_column_names
X_train_dataframe,X_test_dataframe=X_train[train_columns],X_test[train_columns]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# #### 2.2 Train the model and log results using mlflow

# %%
def train_model(X_train,X_test, y_train, y_test,experiment_name,model_name):
    mlflow.set_experiment(experiment_name) 
    print("Training model...")

    #Train the LinearRegression model using the fit method
    with mlflow.start_run() as run:
        model = LinearRegression().fit(X_train_dataframe, y_train)
        score = model.score(X_test_dataframe, y_test)
        mlflow.log_param("score",score)
        mlflow.sklearn.log_model(model,model_name,
                         registered_model_name = model_name)
        
    run_id = run.info.run_id
    return run_id
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
experiment_name,model_name='/Users/<user>/SalesPredictionExperiment','SalesPredictionModel'
run_id=train_model(X_train,X_test, y_train, y_test,experiment_name,model_name)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Training model...
# Registered model &#39;SalesPredictionModel&#39; already exists. Creating a new version of this model...
# 2022/09/07 23:05:25 INFO mlflow.tracking._model_registry.client: Waiting up to 300 seconds for model version to finish creation.                     Model name: SalesPredictionModel, version 29
# Created version &#39;29&#39; of model &#39;SalesPredictionModel&#39;.
# </div>

# %%
model_uri=f"runs:/{run_id}/{model_name}"
print("The MODEL_URI is '{}'".format(model_uri))

# %% [markdown]
# ### 3. Register the  model

# %%
import time
model_version = mlflow.register_model(model_uri=model_uri,name=model_name)
 
# Registering the model takes a few seconds, so add a small delay
time.sleep(15)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Registered model &#39;SalesPredictionModel&#39; already exists. Creating a new version of this model...
# 2022/09/07 23:05:31 INFO mlflow.tracking._model_registry.client: Waiting up to 300 seconds for model version to finish creation.                     Model name: SalesPredictionModel, version 30
# Created version &#39;30&#39; of model &#39;SalesPredictionModel&#39;.
# </div>

# %% [markdown]
# ### 4. Transition the model to production

# %%
from mlflow.tracking import MlflowClient
 
client = MlflowClient()
client.transition_model_version_stage(
  name=model_name,
  version=model_version.version,
  stage="Production",
)

# %% [markdown]
# ### 5. Inference the deployed model by passing the test data

# %%
X_test_dataframe['GROSSAMOUNT_1'] = X_test_dataframe['GROSSAMOUNT_1'].astype(float)
X_test_dataframe['Gross amount'] = X_test_dataframe['Gross amount'].astype(float)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">&lt;command-2615357366207262&gt;:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test_dataframe[&#39;GROSSAMOUNT_1&#39;] = X_test_dataframe[&#39;GROSSAMOUNT_1&#39;].astype(float)
# &lt;command-2615357366207262&gt;:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test_dataframe[&#39;Gross amount&#39;] = X_test_dataframe[&#39;Gross amount&#39;].astype(float)
# </div>

# %%
import pandas as pd
model = mlflow.pyfunc.load_model(f"models:/{model_name}/production")
result=model.predict(X_test_dataframe)
inference_dataframe=pd.DataFrame(result,columns=['prediction_result'])
inference_dataframe
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[38]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>prediction_result</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>58144.612252</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>243003.350000</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>21600.000000</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>58144.612252</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>45710.990000</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>572</th>
#       <td>43674.730000</td>
#     </tr>
#     <tr>
#       <th>573</th>
#       <td>133303.500000</td>
#     </tr>
#     <tr>
#       <th>574</th>
#       <td>35525.240000</td>
#     </tr>
#     <tr>
#       <th>575</th>
#       <td>26642.240000</td>
#     </tr>
#     <tr>
#       <th>576</th>
#       <td>95705.990000</td>
#     </tr>
#   </tbody>
# </table>
# <p>577 rows × 1 columns</p>
# </div>

# %% [markdown]
# ### 6. Store the inferencing result in SAP Data Warehouse Cloud

# %% [markdown]
# #### 6.1 Store the inference result in the pandas dataframe

# %%
X_test['PredictedSalesVolume']=inference_dataframe['prediction_result'].values
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">&lt;command-2615357366207268&gt;:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test[&#39;PredictedSalesVolume&#39;]=inference_dataframe[&#39;prediction_result&#39;].values
# </div>

# %% [markdown]
# #### 6.2 Select the required columns from pandas dataframe

# %%
dwc_write_dataframe=X_test[['Country_Label', 'Country','YEAR_Label', 'YEAR','HarmonizedCountryDimension_COUNTRYCODE','Gross amount', 'Value', 'Value_1', 'Gross amount_1', 'GROSSAMOUNT_1','PredictedSalesVolume']]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# #### 6.3 Renaming the columns in the pandas dataframe

# %%
dwc_write_dataframe.rename(columns = {'Gross amount':'Gross_amount', 'Gross amount_1':'Gross_amount_1'}, inplace = True)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">&lt;command-2615357366207272&gt;:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dwc_write_dataframe.rename(columns = {&#39;Gross amount&#39;:&#39;Gross_amount&#39;, &#39;Gross amount_1&#39;:&#39;Gross_amount_1&#39;}, inplace = True)
# </div>

# %%
dwc_write_dataframe
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[42]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Country_Label</th>
#       <th>Country</th>
#       <th>YEAR_Label</th>
#       <th>YEAR</th>
#       <th>HarmonizedCountryDimension_COUNTRYCODE</th>
#       <th>Gross_amount</th>
#       <th>Value</th>
#       <th>Value_1</th>
#       <th>Gross_amount_1</th>
#       <th>GROSSAMOUNT_1</th>
#       <th>PredictedSalesVolume</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1847</th>
#       <td>Canada</td>
#       <td>Canada</td>
#       <td>2020</td>
#       <td>2020</td>
#       <td>CA</td>
#       <td>58144.612252</td>
#       <td>0E-10</td>
#       <td>0E-10</td>
#       <td>120395.24</td>
#       <td>120395.24</td>
#       <td>58144.612252</td>
#     </tr>
#     <tr>
#       <th>1501</th>
#       <td>France</td>
#       <td>France</td>
#       <td>2021</td>
#       <td>2021</td>
#       <td>FR</td>
#       <td>243003.35</td>
#       <td>0E-10</td>
#       <td>0E-10</td>
#       <td>0.00</td>
#       <td>14536.153063</td>
#       <td>243003.350000</td>
#     </tr>
#     <tr>
#       <th>727</th>
#       <td>Australia</td>
#       <td>Australia</td>
#       <td>2023</td>
#       <td>2023</td>
#       <td>AU</td>
#       <td>21600.00</td>
#       <td>0E-10</td>
#       <td>0E-10</td>
#       <td>0.00</td>
#       <td>14536.153063</td>
#       <td>21600.000000</td>
#     </tr>
#     <tr>
#       <th>1746</th>
#       <td>Australia</td>
#       <td>Australia</td>
#       <td>2020</td>
#       <td>2020</td>
#       <td>AU</td>
#       <td>58144.612252</td>
#       <td>0E-10</td>
#       <td>0E-10</td>
#       <td>132587.98</td>
#       <td>132587.98</td>
#       <td>58144.612252</td>
#     </tr>
#     <tr>
#       <th>611</th>
#       <td>United Kingdom</td>
#       <td>United Kingdom</td>
#       <td>2023</td>
#       <td>2023</td>
#       <td>GB</td>
#       <td>45710.99</td>
#       <td>0E-10</td>
#       <td>0E-10</td>
#       <td>0.00</td>
#       <td>14536.153063</td>
#       <td>45710.990000</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>902</th>
#       <td>India</td>
#       <td>India</td>
#       <td>2022</td>
#       <td>2022</td>
#       <td>IN</td>
#       <td>43674.73</td>
#       <td>0E-10</td>
#       <td>0E-10</td>
#       <td>0.00</td>
#       <td>14536.153063</td>
#       <td>43674.730000</td>
#     </tr>
#     <tr>
#       <th>1007</th>
#       <td>India</td>
#       <td>India</td>
#       <td>2023</td>
#       <td>2023</td>
#       <td>IN</td>
#       <td>133303.50</td>
#       <td>0E-10</td>
#       <td>0E-10</td>
#       <td>0.00</td>
#       <td>14536.153063</td>
#       <td>133303.500000</td>
#     </tr>
#     <tr>
#       <th>199</th>
#       <td>United States</td>
#       <td>United States</td>
#       <td>2023</td>
#       <td>2023</td>
#       <td>US</td>
#       <td>35525.24</td>
#       <td>0E-10</td>
#       <td>0E-10</td>
#       <td>0.00</td>
#       <td>14536.153063</td>
#       <td>35525.240000</td>
#     </tr>
#     <tr>
#       <th>717</th>
#       <td>Australia</td>
#       <td>Australia</td>
#       <td>2021</td>
#       <td>2021</td>
#       <td>AU</td>
#       <td>26642.24</td>
#       <td>0E-10</td>
#       <td>0E-10</td>
#       <td>0.00</td>
#       <td>14536.153063</td>
#       <td>26642.240000</td>
#     </tr>
#     <tr>
#       <th>167</th>
#       <td>United States</td>
#       <td>United States</td>
#       <td>2023</td>
#       <td>2023</td>
#       <td>US</td>
#       <td>95705.99</td>
#       <td>0E-10</td>
#       <td>0E-10</td>
#       <td>0.00</td>
#       <td>14536.153063</td>
#       <td>95705.990000</td>
#     </tr>
#   </tbody>
# </table>
# <p>577 rows × 11 columns</p>
# </div>

# %%
dwc.drop_table('SALES_TABLE')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">2022-09-07 23:05:54,349: fedml_databricks.logger INFO: deleting table...
# </div>

# %% [markdown]
# #### 6.4 Create a table in Data Warehouse Cloud for storing the inference result

# %%
dwc.create_table("CREATE TABLE SALES_TABLE (Country_Label Varchar(20),Country Varchar(20),YEAR_Label Varchar(20),YEAR Varchar(20),HarmonizedCountryDimension_COUNTRYCODE Varchar(20), Gross_amount FLOAT,Value FLOAT,Value_1 FLOAT,Gross_amount_1 FLOAT,GROSSAMOUNT_1 FLOAT,PredictedSalesVolume FLOAT)")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">2022-09-07 23:05:54,486: fedml_databricks.logger INFO: creating table...
# 2022-09-07 23:05:54,486: fedml_databricks.logger INFO: CREATE TABLE SALES_TABLE (Country_Label Varchar(20),Country Varchar(20),YEAR_Label Varchar(20),YEAR Varchar(20),HarmonizedCountryDimension_COUNTRYCODE Varchar(20), Gross_amount FLOAT,Value FLOAT,Value_1 FLOAT,Gross_amount_1 FLOAT,GROSSAMOUNT_1 FLOAT,PredictedSalesVolume FLOAT, INSERTED_AT TIMESTAMP NOT NULL)
# </div>

# %% [markdown]
# #### 6.5 Write the prediction results to 'SALES_TABLE' table in SAP Data Warehouse Cloud

# %%
dwc.insert_into_table('SALES_TABLE',dwc_write_dataframe)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">2022-09-07 23:05:54,625: fedml_databricks.logger INFO: inserting into table...
# 2022-09-07 23:05:54,625: fedml_databricks.logger INFO: INSERT INTO SALES_TABLE (Country_Label, Country, YEAR_Label, YEAR, HarmonizedCountryDimension_COUNTRYCODE, Gross_amount, Value, Value_1, Gross_amount_1, GROSSAMOUNT_1, PredictedSalesVolume, INSERTED_AT) VALUES (:Country_Label, :Country, :YEAR_Label, :YEAR, :HarmonizedCountryDimension_COUNTRYCODE, :Gross_amount, :Value, :Value_1, :Gross_amount_1, :GROSSAMOUNT_1, :PredictedSalesVolume, :INSERTED_AT)
# </div>
