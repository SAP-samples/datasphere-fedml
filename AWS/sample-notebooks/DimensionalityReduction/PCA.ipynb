# %% [markdown]
# ## Scikit-Learn PCA
# ### Using BREASTCANCER_VIEW from DWC. This view has 569 records

# %% [markdown]
# ## Install fedml_aws library

# %%
pip install fedml_aws-1.0.0-py3-none-any.whl --force-reinstall
# Out:
# Processing ./fedml_aws-1.0.0-py3-none-any.whl
# Collecting hdbcli
#   Using cached hdbcli-2.10.13-cp34-abi3-manylinux1_x86_64.whl (11.7 MB)
# Installing collected packages: hdbcli, fedml-aws
#   Attempting uninstall: hdbcli
#     Found existing installation: hdbcli 2.10.13
#     Uninstalling hdbcli-2.10.13:
#       Successfully uninstalled hdbcli-2.10.13
#   Attempting uninstall: fedml-aws
#     Found existing installation: fedml-aws 1.0.0
#     Uninstalling fedml-aws-1.0.0:
#       Successfully uninstalled fedml-aws-1.0.0
# Successfully installed fedml-aws-1.0.0 hdbcli-2.10.13
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Import Libraries

# %%
from fedml_aws import DwcSagemaker
from fedml_aws import DbConnection
import numpy as np
import pandas as pd
import json

# %% [markdown]
# ## Create DwcSagemaker instance to access libraries functions

# %%
dwcs = DwcSagemaker(prefix='scikit-learn/dimRed', 
                    bucket_name='fedml-bucket')

# %% [markdown]
# ## Create DbConnection instance to get data from DWC

# %% [markdown]
# Before running the following cell, you should have a config.json file in the same directory as this notebook with the specified values to allow you to access to DWC.
#
# You should also have the follow view `BREASTCANCER_VIEW` created in your DWC. To gather this data, please refer to https://www.kaggle.com/uciml/breast-cancer-wisconsin-data

# %%
# %%time
db = DbConnection()
res, column_headers = db.get_data_with_headers(table_name="BREASTCANCER_VIEW", size=1)
data = pd.DataFrame(res, columns=column_headers)
data
# Out:
# CPU times: user 63.9 ms, sys: 363 µs, total: 64.3 ms
# Wall time: 209 ms
#            id diagnosis radius_mean texture_mean perimeter_mean area_mean  \
# 0      842302         M       17.99        10.38          122.8      1001
# 1      842517         M       20.57        17.77          132.9      1326
# 2    84300903         M       19.69        21.25            130      1203
# 3    84348301         M       11.42        20.38          77.58     386.1
# 4    84358402         M       20.29        14.34          135.1      1297
# ..        ...       ...         ...          ...            ...       ...
# 564    926424         M       21.56        22.39            142      1479
# 565    926682         M       20.13        28.25          131.2      1261
# 566    926954         M        16.6        28.08          108.3     858.1
# 567    927241         M        20.6        29.33          140.1      1265
# 568     92751         B        7.76        24.54          47.92       181
#
#     smoothness_mean compactness_mean concavity_mean concave points_mean  ...  \
# 0            0.1184           0.2776         0.3001              0.1471  ...
# 1           0.08474          0.07864         0.0869             0.07017  ...
# 2            0.1096           0.1599         0.1974              0.1279  ...
# 3            0.1425           0.2839         0.2414              0.1052  ...
# 4            0.1003           0.1328          0.198              0.1043  ...
# ..              ...              ...            ...                 ...  ...
# 564           0.111           0.1159         0.2439              0.1389  ...
# 565          0.0978           0.1034          0.144             0.09791  ...
# 566         0.08455           0.1023        0.09251             0.05302  ...
# 567          0.1178            0.277         0.3514               0.152  ...
# 568         0.05263          0.04362              0                   0  ...
#
#     texture_worst perimeter_worst area_worst smoothness_worst  \
# 0           17.33           184.6       2019           0.1622
# 1           23.41           158.8       1956           0.1238
# 2           25.53           152.5       1709           0.1444
# 3            26.5           98.87      567.7           0.2098
# 4           16.67           152.2       1575           0.1374
# ..            ...             ...        ...              ...
# 564          26.4           166.1       2027            0.141
# 565         38.25             155       1731           0.1166
# 566         34.12           126.7       1124           0.1139
# 567         39.42           184.6       1821            0.165
# 568         30.37           59.16      268.6          0.08996
#
#     compactness_worst concavity_worst concave points_worst symmetry_worst  \
# 0              0.6656          0.7119               0.2654         0.4601
# 1              0.1866          0.2416                0.186          0.275
# 2              0.4245          0.4504                0.243         0.3613
# 3              0.8663          0.6869               0.2575         0.6638
# 4               0.205             0.4               0.1625         0.2364
# ..                ...             ...                  ...            ...
# 564            0.2113          0.4107               0.2216          0.206
# 565            0.1922          0.3215               0.1628         0.2572
# 566            0.3094          0.3403               0.1418         0.2218
# 567            0.8681          0.9387                0.265         0.4087
# 568           0.06444               0                    0         0.2871
#
#     fractal_dimension_worst column32
# 0                    0.1189     None
# 1                   0.08902     None
# 2                   0.08758     None
# 3                     0.173     None
# 4                   0.07678     None
# ..                      ...      ...
# 564                 0.07115     None
# 565                 0.06637     None
# 566                  0.0782     None
# 567                   0.124     None
# 568                 0.07039     None
#
# [569 rows x 33 columns]

# %%
data.columns
# Out:
# Index(['id', 'diagnosis', 'radius_mean', 'texture_mean', 'perimeter_mean',
#        'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
#        'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
#        'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
#        'fractal_dimension_se', 'radius_worst', 'texture_worst',
#        'perimeter_worst', 'area_worst', 'smoothness_worst',
#        'compactness_worst', 'concavity_worst', 'concave points_worst',
#        'symmetry_worst', 'fractal_dimension_worst', 'column32'],
#       dtype='object')

# %% [markdown]
# ## Train SciKit Model¶
# `train_data` is the data you want to train your model with.
#
# In order to deploy a model to AWS using the Scikit-learn Sagemaker SDK, you must have a script that tells Sagemaker how to train and deploy the model. The path to the script is passed to the `train_sklearn_model` function in the `train_script` parameter.
#
# `instance_type` specifies how much computing power we want AWS to allocate for our services.

# %%
clf = dwcs.train_sklearn_model(data,
                               train_script='pca_script.py',
                               instance_type='ml.c4.xlarge',
                              wait=True,
                              download_output=True,
                              hyperparameters={'n_components':3})
# Out:
# Training data uploaded
# 2021-10-06 23:28:19 Starting - Starting the training job...
# 2021-10-06 23:28:44 Starting - Launching requested ML instancesProfilerReport-1633562899: InProgress
# ......
# 2021-10-06 23:29:44 Starting - Preparing the instances for training.........
# 2021-10-06 23:31:18 Downloading - Downloading input data...
# 2021-10-06 23:31:49 Training - Downloading the training image...
# 2021-10-06 23:32:05 Training - Training image download completed. Training in progress.2021-10-06 23:32:05,643 sagemaker-containers INFO     Imported framework sagemaker_sklearn_container.training
# 2021-10-06 23:32:05,645 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2021-10-06 23:32:05,656 sagemaker_sklearn_container.training INFO     Invoking user training script.
# 2021-10-06 23:32:21,467 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2021-10-06 23:32:21,480 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2021-10-06 23:32:21,494 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2021-10-06 23:32:21,504 sagemaker-training-toolkit INFO     Invoking user script
#
# Training Env:
#
# {
#     "additional_framework_parameters": {},
#     "channel_input_dirs": {
#         "train": "/opt/ml/input/data/train"
#     },
#     "current_host": "algo-1",
#     "framework_module": "sagemaker_sklearn_container.training:main",
#     "hosts": [
#         "algo-1"
#     ],
#     "hyperparameters": {
#         "n_components": 3
#     },
#     "input_config_dir": "/opt/ml/input/config",
#     "input_data_config": {
#         "train": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         }
#     },
#     "input_dir": "/opt/ml/input",
#     "is_master": true,
#     "job_name": "sagemaker-scikit-learn-2021-10-06-23-28-19-137",
#     "log_level": 20,
#     "master_hostname": "algo-1",
#     "model_dir": "/opt/ml/model",
#     "module_dir": "s3://sagemaker-us-east-1-321880606331/sagemaker-scikit-learn-2021-10-06-23-28-19-137/source/sourcedir.tar.gz",
#     "module_name": "pca_script",
#     "network_interface_name": "eth0",
#     "num_cpus": 4,
#     "num_gpus": 0,
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "output_intermediate_dir": "/opt/ml/output/intermediate",
#     "resource_config": {
#         "current_host": "algo-1",
#         "hosts": [
#             "algo-1"
#         ],
#         "network_interface_name": "eth0"
#     },
#     "user_entry_point": "pca_script.py"
# }
#
# Environment variables:
#
# SM_HOSTS=["algo-1"]
# SM_NETWORK_INTERFACE_NAME=eth0
# SM_HPS={"n_components":3}
# SM_USER_ENTRY_POINT=pca_script.py
# SM_FRAMEWORK_PARAMS={}
# SM_RESOURCE_CONFIG={"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"}
# SM_INPUT_DATA_CONFIG={"train":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}}
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_CHANNELS=["train"]
# SM_CURRENT_HOST=algo-1
# SM_MODULE_NAME=pca_script
# SM_LOG_LEVEL=20
# SM_FRAMEWORK_MODULE=sagemaker_sklearn_container.training:main
# SM_INPUT_DIR=/opt/ml/input
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=4
# SM_NUM_GPUS=0
# SM_MODEL_DIR=/opt/ml/model
# SM_MODULE_DIR=s3://sagemaker-us-east-1-321880606331/sagemaker-scikit-learn-2021-10-06-23-28-19-137/source/sourcedir.tar.gz
# SM_TRAINING_ENV={"additional_framework_parameters":{},"channel_input_dirs":{"train":"/opt/ml/input/data/train"},"current_host":"algo-1","framework_module":"sagemaker_sklearn_container.training:main","hosts":["algo-1"],"hyperparameters":{"n_components":3},"input_config_dir":"/opt/ml/input/config","input_data_config":{"train":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","is_master":true,"job_name":"sagemaker-scikit-learn-2021-10-06-23-28-19-137","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-us-east-1-321880606331/sagemaker-scikit-learn-2021-10-06-23-28-19-137/source/sourcedir.tar.gz","module_name":"pca_script","network_interface_name":"eth0","num_cpus":4,"num_gpus":0,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"},"user_entry_point":"pca_script.py"}
# SM_USER_ARGS=["--n_components","3"]
# SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# SM_CHANNEL_TRAIN=/opt/ml/input/data/train
# SM_HP_N_COMPONENTS=3
# PYTHONPATH=/opt/ml/code:/miniconda3/bin:/miniconda3/lib/python37.zip:/miniconda3/lib/python3.7:/miniconda3/lib/python3.7/lib-dynload:/miniconda3/lib/python3.7/site-packages
#
# Invoking script with the following command:
#
# /miniconda3/bin/python pca_script.py --n_components 3
#
#
# ********* Handling Data *********n
#
# storing the test pca data in output/test_pca_data.csv ...
# storing the data in /opt/ml/output/data/test_pca_data.csv
# /miniconda3/lib/python3.7/site-packages/pandas/core/frame.py:4323: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   downcast=downcast,
# 500 rows
#         id diagnosis  ...  fractal_dimension_worst  column32
# 0   921092         B  ...                  0.09938       0.0
# 1  8911834         B  ...                  0.06912       0.0
# 2  9011495         B  ...                  0.07470       0.0
# 3   853401         M  ...                  0.09782       0.0
# 4   867387         B  ...                  0.07071       0.0
#
# [5 rows x 33 columns]
# (500,)
# (500, 32)
# (500, 3)
# [[ 0.02512089  0.21683316  0.10106282  0.22563409  0.21906617  0.14350856
#    0.24020558  0.25787346  0.26029884  0.14587674  0.06771332  0.20564027
#    0.01922261  0.21047574  0.20252488  0.01649856  0.1726074   0.15335342
#    0.18263256  0.05063533  0.10442269  0.22666559  0.10116676  0.23520134
#    0.22419144  0.12512415  0.21133543  0.22884778  0.24932475  0.12851316
#    0.13373076  0.        ]
#  [-0.02170715 -0.23846274 -0.05802569 -0.21984231 -0.23529483  0.18479203
#    0.14587609  0.05994904 -0.03943309  0.18582058  0.36611113 -0.10581391
#    0.09328991 -0.08965832 -0.15203367  0.19947174  0.2312082   0.19923976
#    0.13338934  0.185961    0.27411488 -0.22267075 -0.04104878 -0.20310668
#   -0.22147932  0.17213253  0.14026256  0.0986876  -0.00928861  0.14265392
#    0.27184512 -0.        ]
#  [ 0.08574189 -0.00763622  0.07249605 -0.00863801  0.02966284 -0.11220573
#   -0.07770818  0.00177752 -0.0308088  -0.05149874 -0.01745228  0.26585614
#    0.36492805  0.26417816  0.21668714  0.31117757  0.15787361  0.17881521
#    0.21926387  0.2754271   0.22151873 -0.04791118 -0.03919459 -0.04895426
#   -0.01319291 -0.26928593 -0.23307185 -0.16911479 -0.17492691 -0.27184916
#   -0.22398246 -0.        ]]
# [0.42975217 0.18252208 0.0926299 ]
# storing the pca data in output/pca_data.csv ...
# storing the data in /opt/ml/output/data/pca_data.csv
# storing the model....
# saved model!
# 2021-10-06 23:32:24,053 sagemaker-containers INFO     Reporting training SUCCESS
#
# 2021-10-06 23:32:45 Uploading - Uploading generated training model
# 2021-10-06 23:32:45 Completed - Training job completed
# Training seconds: 74
# Billable seconds: 74
#
# 2021-10-06 23:32:45 Starting - Preparing the instances for training
# 2021-10-06 23:32:45 Downloading - Downloading input data
# 2021-10-06 23:32:45 Training - Training image download completed. Training in progress.
# 2021-10-06 23:32:45 Uploading - Uploading generated training model
# 2021-10-06 23:32:45 Completed - Training job completed
# Output files saved in output-2021-10-06-23-33-03
