# %% [markdown]
# ## Scikit-Learn Data Preprocessor
# ### Using TITANIC_VIEW from DWC. This view has 861 records

# %% [markdown]
# ## Install fedml_aws library

# %%
pip install fedml_aws-1.0.0-py3-none-any.whl --force-reinstall
# Out:
# Processing ./fedml_aws-1.0.0-py3-none-any.whl
# Collecting hdbcli
#   Using cached hdbcli-2.10.13-cp34-abi3-manylinux1_x86_64.whl (11.7 MB)
# Installing collected packages: hdbcli, fedml-aws
#   Attempting uninstall: hdbcli
#     Found existing installation: hdbcli 2.10.13
#     Uninstalling hdbcli-2.10.13:
#       Successfully uninstalled hdbcli-2.10.13
#   Attempting uninstall: fedml-aws
#     Found existing installation: fedml-aws 1.0.0
#     Uninstalling fedml-aws-1.0.0:
#       Successfully uninstalled fedml-aws-1.0.0
# Successfully installed fedml-aws-1.0.0 hdbcli-2.10.13
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Import Libraries

# %%
from fedml_aws import DwcSagemaker
from fedml_aws import DbConnection
import numpy as np
import pandas as pd
import json

# %% [markdown]
# ## Create DwcSagemaker instance to access libraries functions

# %%
dwcs = DwcSagemaker(prefix='scikit-learn/data-preprocessing', 
                    bucket_name='fedml-bucket')

# %% [markdown]
# ## Create DbConnection instance to get data from DWC

# %% [markdown]
# Before running the following cell, you should have a config.json file in the same directory as this notebook with the specified values to allow you to access to DWC.
#
# You should also have the follow view `TITANIC_VIEW` created in your DWC. To gather this data, please refer to https://www.kaggle.com/c/titanic/data and download the train.csv file.

# %%
# %%time
db = DbConnection()
data = db.execute_query('SELECT * FROM %s' % ('SCE.TITANIC_VIEW'))
data = pd.DataFrame(data[0], columns=data[1])
data
# Out:
# CPU times: user 49.2 ms, sys: 3.55 ms, total: 52.8 ms
# Wall time: 110 ms
#      PassengerId  Survived  Pclass  \
# 0              1     False       3
# 1              2      True       1
# 2              3      True       3
# 3              4      True       1
# 4              5     False       3
# ..           ...       ...     ...
# 886          887     False       2
# 887          888      True       1
# 888          889     False       3
# 889          890      True       1
# 890          891     False       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male    22      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female    38      1
# 2                               Heikkinen, Miss. Laina  female    26      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female    35      1
# 4                             Allen, Mr. William Henry    male    35      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male    27      0
# 887                       Graham, Miss. Margaret Edith  female    19      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female  None      1
# 889                              Behr, Mr. Karl Howell    male    26      0
# 890                                Dooley, Mr. Patrick    male    32      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171     7.25              S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282    7.925              S
# 3        0            113803     53.1  C123        S
# 4        0            373450     8.05              S
# ..     ...               ...      ...   ...      ...
# 886      0            211536       13              S
# 887      0            112053       30   B42        S
# 888      2        W./C. 6607    23.45              S
# 889      0            111369       30  C148        C
# 890      0            370376     7.75              Q
#
# [891 rows x 12 columns]

# %% [markdown]
# ## Train SciKit Model¶
# `train_data` is the data you want to train your model with.
#
# In order to deploy a model to AWS using the Scikit-learn Sagemaker SDK, you must have a script that tells Sagemaker how to train and deploy the model. The path to the script is passed to the `train_sklearn_model` function in the `train_script` parameter.
#
# `instance_type` specifies how much computing power we want AWS to allocate for our services.

# %%
clf = dwcs.train_sklearn_model(data,
                               train_script='preprocessor_script.py',
                               instance_type='ml.c4.xlarge',
                              wait=True,
                              download_output=True,
                              logs='All')
# Out:
# Training data uploaded
# 2021-10-06 22:40:22 Starting - Starting the training job...
# 2021-10-06 22:40:46 Starting - Launching requested ML instancesProfilerReport-1633560021: InProgress
# ......
# 2021-10-06 22:41:47 Starting - Preparing the instances for training............
# 2021-10-06 22:43:47 Downloading - Downloading input data...
# 2021-10-06 22:44:07 Training - Downloading the training image..2021-10-06 22:44:30,473 sagemaker-containers INFO     Imported framework sagemaker_sklearn_container.training
# 2021-10-06 22:44:30,475 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2021-10-06 22:44:30,486 sagemaker_sklearn_container.training INFO     Invoking user training script.
# 2021-10-06 22:44:30,967 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2021-10-06 22:44:33,999 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2021-10-06 22:44:34,013 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2021-10-06 22:44:34,023 sagemaker-training-toolkit INFO     Invoking user script
#
# Training Env:
#
# {
#     "additional_framework_parameters": {},
#     "channel_input_dirs": {
#         "train": "/opt/ml/input/data/train"
#     },
#     "current_host": "algo-1",
#     "framework_module": "sagemaker_sklearn_container.training:main",
#     "hosts": [
#         "algo-1"
#     ],
#     "hyperparameters": {},
#     "input_config_dir": "/opt/ml/input/config",
#     "input_data_config": {
#         "train": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         }
#     },
#     "input_dir": "/opt/ml/input",
#     "is_master": true,
#     "job_name": "sagemaker-scikit-learn-2021-10-06-22-40-21-302",
#     "log_level": 20,
#     "master_hostname": "algo-1",
#     "model_dir": "/opt/ml/model",
#     "module_dir": "s3://sagemaker-us-east-1-321880606331/sagemaker-scikit-learn-2021-10-06-22-40-21-302/source/sourcedir.tar.gz",
#     "module_name": "preprocessor_script",
#     "network_interface_name": "eth0",
#     "num_cpus": 4,
#     "num_gpus": 0,
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "output_intermediate_dir": "/opt/ml/output/intermediate",
#     "resource_config": {
#         "current_host": "algo-1",
#         "hosts": [
#             "algo-1"
#         ],
#         "network_interface_name": "eth0"
#     },
#     "user_entry_point": "preprocessor_script.py"
# }
#
# Environment variables:
#
# SM_HOSTS=["algo-1"]
# SM_NETWORK_INTERFACE_NAME=eth0
# SM_HPS={}
# SM_USER_ENTRY_POINT=preprocessor_script.py
# SM_FRAMEWORK_PARAMS={}
# SM_RESOURCE_CONFIG={"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"}
# SM_INPUT_DATA_CONFIG={"train":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}}
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_CHANNELS=["train"]
# SM_CURRENT_HOST=algo-1
# SM_MODULE_NAME=preprocessor_script
# SM_LOG_LEVEL=20
# SM_FRAMEWORK_MODULE=sagemaker_sklearn_container.training:main
# SM_INPUT_DIR=/opt/ml/input
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=4
# SM_NUM_GPUS=0
# SM_MODEL_DIR=/opt/ml/model
# SM_MODULE_DIR=s3://sagemaker-us-east-1-321880606331/sagemaker-scikit-learn-2021-10-06-22-40-21-302/source/sourcedir.tar.gz
# SM_TRAINING_ENV={"additional_framework_parameters":{},"channel_input_dirs":{"train":"/opt/ml/input/data/train"},"current_host":"algo-1","framework_module":"sagemaker_sklearn_container.training:main","hosts":["algo-1"],"hyperparameters":{},"input_config_dir":"/opt/ml/input/config","input_data_config":{"train":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","is_master":true,"job_name":"sagemaker-scikit-learn-2021-10-06-22-40-21-302","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-us-east-1-321880606331/sagemaker-scikit-learn-2021-10-06-22-40-21-302/source/sourcedir.tar.gz","module_name":"preprocessor_script","network_interface_name":"eth0","num_cpus":4,"num_gpus":0,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"},"user_entry_point":"preprocessor_script.py"}
# SM_USER_ARGS=[]
# SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# SM_CHANNEL_TRAIN=/opt/ml/input/data/train
# PYTHONPATH=/opt/ml/code:/miniconda3/bin:/miniconda3/lib/python37.zip:/miniconda3/lib/python3.7:/miniconda3/lib/python3.7/lib-dynload:/miniconda3/lib/python3.7/site-packages
#
# Invoking script with the following command:
#
# /miniconda3/bin/python preprocessor_script.py
#
#
# The scikit-learn version is 0.23.2.
#
#
# ********* Handling Data *********
#
#
# training data
#
#      PassengerId  Survived  Pclass  ... Fare Cabin  Embarked
# 0              1         0       3  ...    7   NaN         S
# 1              2         1       1  ...   71   C85         C
# 2              3         1       3  ...    7   NaN         S
# 3              4         1       1  ...   53  C123         S
# 4              5         0       3  ...    8   NaN         S
# ..           ...       ...     ...  ...  ...   ...       ...
# 886          887         0       2  ...   13   NaN         S
# 887          888         1       1  ...   30   B42         S
# 888          889         0       3  ...   23   NaN         S
# 889          890         1       1  ...   30  C148         C
# 890          891         0       3  ...    7   NaN         Q
#
# [891 rows x 12 columns]
#
#
# % of passanger survived in train dataset:  38.38383838383838
#
# % of passanger not survived in train dataset:  61.61616161616162
#
#
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64
#
#
# Survived values: [0 1]
# *** Dropping columns ... *****
#
#
# The following columns are categorical ['Sex', 'Embarked']
#
# The following columns are numerical ['PassengerId', 'Pclass', 'Age', 'SibSp', 'Parch', 'Fare']
#
#
# train num missing cols:
# PassengerId    False
# Pclass         False
# Age             True
# SibSp          False
# Parch          False
# Fare           False
# dtype: bool
#
# train obj missing cols:
# Sex         False
# Embarked     True
# dtype: bool
# ['S' 'C' 'Q' nan]
# 644 168 77
#
#
# ******* Handle the Embarked columns and Use the SimpleImputer to impute values for numerical NaN's and One hot encoder for categories ********
# The category that appears most often in train['Embarked'] is  S
# ['S' 'C' 'Q' '-1']
# preprocessor_script.py:81: UserWarning: Transformer num (type SimpleImputer) does not provide get_feature_names. Will return input column names if available
#   % (str(name), type(trans).__name__))
# preprocessor_script.py:81: UserWarning: Transformer simpleimputer (type SimpleImputer) does not provide get_feature_names. Will return input column names if available
#   % (str(name), type(trans).__name__))
#      num__PassengerId  num__Pclass  ...  onehotencoder__x1_Q  onehotencoder__x1_S
# 0                 1.0          3.0  ...                  0.0                  1.0
# 1                 2.0          1.0  ...                  0.0                  0.0
# 2                 3.0          3.0  ...                  0.0                  1.0
# 3                 4.0          1.0  ...                  0.0                  1.0
# 4                 5.0          3.0  ...                  0.0                  1.0
# ..                ...          ...  ...                  ...                  ...
# 886             887.0          2.0  ...                  0.0                  1.0
# 887             888.0          1.0  ...                  0.0                  1.0
# 888             889.0          3.0  ...                  0.0                  1.0
# 889             890.0          1.0  ...                  0.0                  0.0
# 890             891.0          3.0  ...                  1.0                  0.0
#
# [891 rows x 11 columns]
# storing the preprocessed data in /opt/ml/output/data/preprocessed_data.csv
# Saving labels to /opt/ml/output/data/labels.csv
# saved model!
# 2021-10-06 22:44:37,121 sagemaker-containers INFO     Reporting training SUCCESS
#
# 2021-10-06 22:44:47 Uploading - Uploading generated training model
# 2021-10-06 22:44:47 Completed - Training job completed
# Training seconds: 76
# Billable seconds: 76
#
# 2021-10-06 22:44:47 Starting - Preparing the instances for training
# 2021-10-06 22:44:47 Downloading - Downloading input data
# 2021-10-06 22:44:47 Training - Training image download completed. Training in progress.
# 2021-10-06 22:44:47 Uploading - Uploading generated training model
# 2021-10-06 22:44:47 Completed - Training job completed
# Output files saved in output-2021-10-06-22-45-04
